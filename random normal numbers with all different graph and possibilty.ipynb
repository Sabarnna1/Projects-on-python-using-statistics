# %%
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(123)
sigma=1
mu=100
sample=[np.random.normal(mu,sigma) for _ in range(1000000)]
sample
sns.barplot(sample)

# %%
sns.distplot(sample)

# %%
sns.boxplot(sample)

# %%
sns.distplot(sample,kde=False)

# %%
sns.distplot(sample,kde=False,color='red')

# %%
sns.distplot(sample,kde=False,color='y')
